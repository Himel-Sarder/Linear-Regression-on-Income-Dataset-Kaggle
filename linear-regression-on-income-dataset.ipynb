# %% [markdown]
# ### ✅ https://www.linkedin.com/in/himel-sarder/

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Loading Dataset

# %%
df = pd.read_csv('/kaggle/input/regressiondata/income_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    income  happiness
# 0           1  3.862647   2.314489
# 1           2  4.979381   3.433490
# 2           3  4.923957   4.599373
# 3           4  3.214372   2.791114
# 4           5  7.196409   5.596398

# %%
df.shape
# Out:
# (498, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  498 non-null    int64
#  1   income      498 non-null    float64
#  2   happiness   498 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 11.8 KB

# %%
# Scatter plot to check linearity
plt.scatter(df['income'], df['happiness'], alpha=0.7, color='blue')
plt.title('Income vs Happiness')
plt.xlabel('Income')
plt.ylabel('Happiness')
plt.show()

# %%
# Check for outliers
sns.boxplot(x=df['income'])
plt.title('Boxplot of Income')
plt.show()

# %%
X = df.iloc[:,1:2]
y = df.iloc[:,-1]

# %% [markdown]
# ## X: Selects the second column (income) as the feature.
# ## y: Selects the last column (happiness) as the target

# %%
X
# Out:
#        income
# 0    3.862647
# 1    4.979381
# 2    4.923957
# 3    3.214372
# 4    7.196409
# ..        ...
# 493  5.249209
# 494  3.471799
# 495  6.087610
# 496  3.440847
# 497  4.530545
#
# [498 rows x 1 columns]

# %%
y
# Out:
# 0      2.314489
# 1      3.433490
# 2      4.599373
# 3      2.791114
# 4      5.596398
#          ...
# 493    4.568705
# 494    2.535002
# 495    4.397451
# 496    2.070664
# 497    3.710193
# Name: happiness, Length: 498, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train
# Out:
#        income
# 53   5.482862
# 334  2.381385
# 152  3.681486
# 377  4.772059
# 476  5.237893
# ..        ...
# 22   2.428752
# 72   1.506275
# 493  5.249209
# 15   2.559166
# 168  6.143150
#
# [398 rows x 1 columns]

# %%
X_test
# Out:
#        income
# 395  6.195004
# 223  6.377376
# 312  3.614745
# 179  5.189031
# 412  6.768336
# ..        ...
# 491  2.482382
# 393  5.741725
# 120  5.711264
# 364  1.890327
# 188  3.897738
#
# [100 rows x 1 columns]

# %%
y_train
# Out:
# 53     3.857424
# 334    2.176322
# 152    3.036820
# 377    3.554600
# 476    3.342749
#          ...
# 22     1.200786
# 72     1.308487
# 493    4.568705
# 15     2.898583
# 168    4.927133
# Name: happiness, Length: 398, dtype: float64

# %%
y_test
# Out:
# 395    4.058312
# 223    5.079476
# 312    2.901789
# 179    4.767596
# 412    5.910285
#          ...
# 491    0.548365
# 393    3.776485
# 120    3.901170
# 364    2.481624
# 188    2.799747
# Name: happiness, Length: 100, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([4.61136034, 4.74097829, 2.77748749, 3.89638306, 5.01884598,
#        2.78995245, 3.74737829, 1.92079696, 3.24322412, 2.74652107,
#        4.82903679, 4.03196541, 4.75096529, 5.26843318, 1.36246853,
#        3.54044027, 5.50198771, 2.72460611, 5.11024121, 2.62480178,
#        2.92852471, 2.06185697, 1.3287457 , 2.69478754, 4.10653795,
#        5.44235502, 3.58838672, 2.81027453, 2.07727532, 5.40447488,
#        4.20654894, 3.58353872, 3.99275939, 1.68666302, 4.47404893,
#        2.72472211, 3.17676767, 1.5345947 , 2.12310002, 3.41892281,
#        2.70461734, 3.92351182, 3.6443335 , 4.11213195, 4.83539358,
#        3.21540055, 3.17378567, 2.33809548, 4.70033499, 4.26849084,
#        1.30619318, 2.54182414, 1.82494859, 3.51153932, 1.61886511,
#        3.54873896, 2.759206  , 1.40273875, 2.67589075, 4.0504115 ,
#        3.2329332 , 1.28452928, 3.60829093, 3.21018718, 2.65389237,
#        2.88395145, 1.99761435, 1.33813377, 3.80592613, 5.36855314,
# ...

# %%
y_test
# Out:
# 395    4.058312
# 223    5.079476
# 312    2.901789
# 179    4.767596
# 412    5.910285
#          ...
# 491    0.548365
# 393    3.776485
# 120    3.901170
# 364    2.481624
# 188    2.799747
# Name: happiness, Length: 100, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# y_test: actual values
# y_pred: predicted values

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# Calculate R-squared (R²)
r2 = r2_score(y_test, y_pred)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 0.5515786593642154
# Mean Squared Error: 0.4616028153050869
# R-squared: 0.765589266021235

# %%
plt.scatter(df['income'],df['happiness'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('Income')
plt.ylabel('Happiness')
# Out:
# Text(0, 0.5, 'Happiness')

# %%
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Root Mean Squared Error: 0.6794135819256831

# %%
# Adjusted R2 score
X_test.shape
# Out:
# (100, 1)

# %%
print("Adjusted R2 Score : ")
1 - ((1-r2)*(100-1))/(100-1-2)
# Out:
# Adjusted R2 Score :
# 0.7607560550113636

# %%
import pickle

# %%
pickle.dump(lr, open('Mymodel.pkl', 'wb'))

# %% [markdown]
# # ***improving my SLR model:***

# %% [markdown]
# # Normalization

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df['income_scaled'] = scaler.fit_transform(df[['income']])

# %%
df.head()
# Out:
#    Unnamed: 0    income  happiness  income_scaled
# 0           1  3.862647   2.314489      -0.348117
# 1           2  4.979381   3.433490       0.295244
# 2           3  4.923957   4.599373       0.263313
# 3           4  3.214372   2.791114      -0.721594
# 4           5  7.196409   5.596398       1.572494

# %%
plt.scatter(df['income_scaled'],df['happiness'])
plt.xlabel('income_scaled')
plt.ylabel('happiness')
# Out:
# Text(0, 0.5, 'happiness')

# %%
X = df.iloc[:,1:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#        income
# 0    3.862647
# 1    4.979381
# 2    4.923957
# 3    3.214372
# 4    7.196409
# ..        ...
# 493  5.249209
# 494  3.471799
# 495  6.087610
# 496  3.440847
# 497  4.530545
#
# [498 rows x 1 columns]

# %%
y
# Out:
# 0     -0.348117
# 1      0.295244
# 2      0.263313
# 3     -0.721594
# 4      1.572494
#          ...
# 493    0.450694
# 494   -0.573288
# 495    0.933704
# 496   -0.591120
# 497    0.036665
# Name: income_scaled, Length: 498, dtype: float64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([ 0.99557528,  1.10064172, -0.49093561,  0.41602501,  1.32587727,
#        -0.48083168,  0.29524389, -1.18535659, -0.11341621, -0.51603654,
#         1.17202067,  0.52592611,  1.10873704,  1.52818905, -1.63792957,
#         0.12750292,  1.71750498, -0.53380049,  1.39996091, -0.61470044,
#        -0.36850702, -1.07101538, -1.66526481, -0.55797099,  0.58637353,
#         1.66916759,  0.16636762, -0.4643589 , -1.05851749,  1.63846249,
#         0.667441  ,  0.1624379 ,  0.49414627, -1.37514218,  0.88427263,
#        -0.53370646, -0.16728485, -1.49840658, -1.02137265,  0.02900261,
#        -0.5500031 ,  0.43801519,  0.21171727,  0.59090794,  1.17717339,
#        -0.13596959, -0.16970201, -0.84710043,  1.06769685,  0.71765021,
#        -1.68354555, -0.68196092, -1.2630499 ,  0.10407622, -1.43009819,
#         0.13422971, -0.50575431, -1.60528711, -0.57328846,  0.54087824,
#        -0.12175788, -1.701106  ,  0.18250168, -0.14019548, -0.59112002,
# ...

# %%
# Calculate metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Absolute Error: 3.505529200253932e-16
# Mean Squared Error: 1.8665342649023334e-31
# R-squared: 1.0

# %% [markdown]
# These values indicate that your model has drastically improved! Let's break down what each metric means in this context:
#
# 1. **Mean Absolute Error (MAE) = 3.51e-16**:
#    - This is extremely close to zero, which suggests that the predictions are nearly identical to the actual values. A value this small indicates that your model is performing very well.
#
# 2. **Mean Squared Error (MSE) = 1.87e-31**:
#    - This is also very close to zero. Since MSE squares the errors, the fact that it's this small further supports that your model's predictions are almost perfect.
#
# 3. **R-squared = 1.0**:
#    - This is the best possible value for R-squared, indicating that your model explains 100% of the variance in the data. In other words, your model perfectly fits the data.
#
# ### Conclusion:
# These values suggest that your model is performing excellently and that the predictions are almost identical to the actual values. This could happen if:
# - Your model is overfitting (especially if you used a very small or simple dataset).
# - The data is almost perfectly linear or the features and target are highly correlated.
#
# ### Recommendations:
# - **Check for Overfitting**: If you have a small dataset, try testing your model on new, unseen data to ensure it generalizes well.
# - **Cross-Validation**: If possible, use cross-validation to check the model's performance on different splits of the data.

# %%
# Check lengths
print(len(y), len(y_pred))

# If necessary, use the correct data
y_test = y_test[:len(y_pred)]  # Align y_test to y_pred

# Now calculate residuals
residuals = y_test - y_pred
plt.scatter(y_pred, residuals, alpha=0.7, color='red')
plt.axhline(0, linestyle='--', color='black')
plt.title('Residual Plot')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.show()
# Out:
# 498 100

# %%
sns.displot(residuals, kind='kde')

# %%
# QQ Plot
import scipy as sp

fig, ax = plt.subplots(figsize=(6,4))
sp.stats.probplot(residuals, plot=ax, fit=True)
plt.show( )

# %% [markdown]
# ## ***Thank You😻***
